# %% [markdown]
# # Proyecto Modulo 2
#
# # Amortización de un automóvil

# %% [markdown]
# <font color="cian">**Objetivo general**</font>
#
#
# + Buscar la mejor opción para sacar un automóvil a crédito considerando tres opciones como las principales.
#
#
# <font color="cian">**Objetivos específicos**</font>
#
# + Analizar las tres diferentes opciones que pueden considerarse como las mejores para obtener así un automóvil nuevo.
#
# + Realizar comparaciones entre ellas de acuerdo a las tasas de interés que manejan, así como los pagos que se harán cada mes.
#
# + Concluir respecto a cada variable que se requiere al pagar para entonces sacar el auto en la opción que más convenga.

# %% [markdown]
# <font color="blue">**Problema a amortizar**</font>
#
# Una persona desea comprar a crédito un automóvil Ford Figo 2018 energy TM de 5 puertas 1.5 L con precio de contado de $\$208,300$ pero requiere hacerlo a crédito buscando entre tres opciones que le parecen las mejores; estas son:
# + En la agencia
# + En banco Banamex
# + En banco Santander
#
# El plazo que se requiere es a $3$ años contando a partir de noviembre 2018.

# %%
import pandas as pd
from datetime import date
import numpy as np
from collections import OrderedDict
from dateutil.relativedelta import *
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize
from datetime import date

# %%
def amortizacion(capital, tasa, años, pmt, enganche, fecha_inicio, pagos_año):

    # inicializa las variables
    p = 1
    ini_balance = capital
    fin_balance = capital
    
    while fin_balance > 0:
        
        # Recalcular el interés basado en el balance 
        interes = round(((tasa/pagos_año) * ini_balance), 2)
        
        # Determine el pago según si este período pagará o no el préstamo
        pmt = min(pmt, ini_balance + interes)
        capital = pmt - interes
        
        # Asegúrese de que el pago adicional se ajuste si el préstamo se está pagando
        enganche = min(enganche, ini_balance - capital)
        fin_balance = ini_balance - (capital + enganche)

        yield OrderedDict([('Mes',fecha_inicio),
                           ('Periodo', p),
                           ('Balance inicial', ini_balance),
                           ('Pago', pmt),
                           ('Capital', capital),
                           ('Interes', interes),
                           ('Enganche', enganche),
                           ('Balance final', fin_balance)])
        
        # Incrementar el contador, saldo y fecha.
        p += 1
        fecha_inicio += relativedelta(months=1)
        ini_balance = fin_balance

# %%
def amortizacion_tabla(capital, tasa, años,
                       enganche=0, pagos_año=12, fecha_inicio=date.today()):

    # El pago se mantiene constante según los términos originales del préstamo.
    pago = -round(np.pmt(tasa/pagos_año, años*pagos_año, capital), 2)
    
    # Genera la tabla y ordena las columnas resultantes para su conveniencia.
    tabla = pd.DataFrame(amortizacion(capital, tasa, años, pago,
                                     enganche, fecha_inicio, pagos_año))
    tabla = tabla[["Periodo", "Mes", "Balance inicial", "Pago", "Interes", 
                         "Capital", "Enganche", "Balance final"]]
    
    # Convertir a un objeto de fecha
    tabla["Mes"] = pd.to_datetime(tabla["Mes"])
    
    #Tabla de estadística de resumen
    fecha_final = tabla["Mes"].iloc[-1]
    res = pd.Series([fecha_final, tabla["Periodo"].count(), tasa,
                       años, capital, pago, enganche,
                       tabla["Interes"].sum()],
                       index=["Fecha de termino", "Número de pagos", "Tasa de interes", "Años", "Capital",
                             "Pago", "Enganche", "Interes total"])
# 35       36 2021-10-01          5609.10  5668.70    59.83  5608.87         0
# 36       37 2021-11-01             0.23     0.23     0.00     0.23         0
#
#     Balance final
# 0       164854.01
# 1       160943.75
# 2       156991.78
# 3       152997.66
# 4       148960.94
# 5       144881.16
# 6       140757.86
# 7       136590.58
# 8       132378.85
# 9       128122.19
# 10      123820.13
# 11      119472.18
# 12      115077.85
# 13      110636.65
# 14      106148.07
# 15      101611.62
# 16       97026.78
# 17       92393.03
# 18       87709.86
# 19       82976.73
# 20       78193.12
# 21       73358.48
# 22       68472.27
# 23       63533.94
# 24       58542.94
# 25       53498.70
# 26       48400.65
# 27       43248.22
# 28       38040.83
# 29       32777.90
# 30       27458.83
# 31       22083.02
# 32       16649.87
# 33       11158.77
# 34        5609.10
# 35           0.23
# 36           0.00

# %%
df.head()
# Out:
#    Periodo        Mes  Balance inicial    Pago  Interes  Capital  Enganche  \
# 0        1 2018-11-01        168723.00  5668.7  1799.71  3868.99         0
# 1        2 2018-12-01        164854.01  5668.7  1758.44  3910.26         0
# 2        3 2019-01-01        160943.75  5668.7  1716.73  3951.97         0
# 3        4 2019-02-01        156991.78  5668.7  1674.58  3994.12         0
# 4        5 2019-03-01        152997.66  5668.7  1631.98  4036.72         0
#
#    Balance final
# 0      164854.01
# 1      160943.75
# 2      156991.78
# 3      152997.66
# 4      148960.94

# %%
df.tail()
# Out:
#     Periodo        Mes  Balance inicial     Pago  Interes  Capital  Enganche  \
# 32       33 2021-07-01         22083.02  5668.70   235.55  5433.15         0
# 33       34 2021-08-01         16649.87  5668.70   177.60  5491.10         0
# 34       35 2021-09-01         11158.77  5668.70   119.03  5549.67         0
# 35       36 2021-10-01          5609.10  5668.70    59.83  5608.87         0
# 36       37 2021-11-01             0.23     0.23     0.00     0.23         0
#
#     Balance final
# 32       16649.87
# 33       11158.77
# 34        5609.10
# 35           0.23
# 36           0.00

# %% [markdown]
# **Banamex**

# %% [markdown]
# **Santander**

# %% [markdown]
# - Tasa de interes: 13.25% anual
# - Enganche: $0
# - Plazo: 3 años
#
# - Credito: $208,300

# %%
df, res = amortizacion_tabla(208300, 0.1325, 3, enganche=0, fecha_inicio=date(2018, 11,1))

# %%
res
# Out:
# Fecha de termino    2021-10-01 00:00:00
# Número de pagos                      36
# Tasa de interes                  0.1325
# Años                                  3
# Capital                          208300
# Pago                            7043.56
# Enganche                              0
# Interes total                   45268.1
# dtype: object

# %%
df
# Out:
#     Periodo        Mes  Balance inicial     Pago  Interes  Capital  Enganche  \
# 0         1 2018-11-01        208300.00  7043.56  2299.98  4743.58         0
# 1         2 2018-12-01        203556.42  7043.56  2247.60  4795.96         0
# 2         3 2019-01-01        198760.46  7043.56  2194.65  4848.91         0
# 3         4 2019-02-01        193911.55  7043.56  2141.11  4902.45         0
# 4         5 2019-03-01        189009.10  7043.56  2086.98  4956.58         0
# 5         6 2019-04-01        184052.52  7043.56  2032.25  5011.31         0
# 6         7 2019-05-01        179041.21  7043.56  1976.91  5066.65         0
# 3        4 2019-02-01        193911.55  7043.56  2141.11  4902.45         0
# 4        5 2019-03-01        189009.10  7043.56  2086.98  4956.58         0
#
#    Balance final
# 0      203556.42
# 1      198760.46
# 2      193911.55
# 3      189009.10
# 4      184052.52

# %%
df.tail()
# Out:
#     Periodo        Mes  Balance inicial     Pago  Interes  Capital  Enganche  \
# 31       32 2021-06-01         34080.57  7043.56   376.31  6667.25         0
# 32       33 2021-07-01         27413.32  7043.56   302.69  6740.87         0
# 33       34 2021-08-01         20672.45  7043.56   228.26  6815.30         0
# 34       35 2021-09-01         13857.15  7043.56   153.01  6890.55         0
# 35       36 2021-10-01          6966.60  7043.52    76.92  6966.60         0
#
#     Balance final
# 31       27413.32
# 32       20672.45
# 33       13857.15
# 34        6966.60
# 35           0.00

# %% [markdown]
# # Comparación

# %%
tabla1, res1 = amortizacion_tabla(168723, .128, 3, enganche=0, fecha_inicio=date(2018,11,1))
tabla2, res2 = amortizacion_tabla(208300, .04, 3, enganche=0, fecha_inicio=date(2018,11,1))
tabla3, res3 = amortizacion_tabla(208300, .1325, 3, enganche=0, fecha_inicio=date(2018,11,1))

# %%
pd.DataFrame([res1, res2, res3])
# Out:
#   Fecha de termino  Número de pagos  Tasa de interes  Años  Capital     Pago  \
# 0       2021-11-01               37           0.1280     3   168723  5668.70
# 1       2021-10-01               36           0.0400     3   208300  6149.85
# 2       2021-10-01               36           0.1325     3   208300  7043.56
#
#    Enganche  Interes total
# 0         0       35350.43
# 1         0       13094.43
# 2         0       45268.12

# %%
# %matplotlib inline
plt.style.use('ggplot')

# %%
fig, ax = plt.subplots(1, 1)
tabla1.plot(x='Mes', y='Balance final', label="Agencia", ax=ax)
tabla2.plot(x='Mes', y='Balance final', label="Banamex", ax=ax)
tabla3.plot(x='Mes', y='Balance final', label="Santander", ax=ax)
plt.title("Pay Off Timelines");

# %%
def make_plot_data(schedule, stats):
    """Create a dataframe with annual interest totals, and a descriptive label"""
    y = schedule.set_index('Month')['Interest'].resample("A").sum().reset_index()
    y["Year"] = y["Month"].dt.year
    y.set_index('Year', inplace=True)
    y.drop('Month', 1, inplace=True)
    label="{} years at {}% with additional payment of ${}".format(stats['Years'], stats['Interest Rate']*100, stats['Additional Payment'])
    return y, label
    
y1, label1 = make_plot_data(schedule1, stats1)
y2, label2 = make_plot_data(schedule2, stats2)
y3, label3 = make_plot_data(schedule3, stats3)

y = pd.concat([y1, y2, y3], axis=1)

# %%
figsize(7,5)
fig, ax = plt.subplots(1, 1)
y.plot(kind="bar", ax=ax)

plt.legend([label1, label2, label3], loc=1, prop={'size':10})
plt.title("Interest Payments");

# %%
additional_payments = [0, 50, 200, 500]
fig, ax = plt.subplots(1, 1)

for pmt in additional_payments:
    result, _ = amortization_table(100000, .04, 30, addl_principal=pmt, start_date=date(2016,1,1))
    ax.plot(result['Month'], result['End Balance'], label='Addl Payment = ${}'.format(str(pmt)))
plt.title("Pay Off Timelines")
plt.ylabel("Balance")
ax.legend();
